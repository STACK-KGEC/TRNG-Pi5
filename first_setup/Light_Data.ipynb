# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
light_data_path = "/home/admin/Python/light_data.csv"

data = pd.read_csv("/home/admin/Python/light_data.csv")
data['timestamp'] = pd.to_datetime(data['timestamp'])
data
# Out:
#                      timestamp       lux
# 0   2025-07-03 23:34:23.595410  3.333333
# 1   2025-07-03 23:34:23.786396  3.333333
# 2   2025-07-03 23:34:23.977400  3.333333
# 3   2025-07-03 23:34:24.168394  3.333333
# 4   2025-07-03 23:34:24.359403  3.333333
# ..                         ...       ...
# 132 2025-07-03 23:34:48.834557  3.333333
# 133 2025-07-03 23:34:49.025622  3.333333
# 134 2025-07-03 23:34:49.216694  3.333333
# 135 2025-07-03 23:34:49.407748  3.333333
# 136 2025-07-03 23:34:49.598816  3.333333
#
# [137 rows x 2 columns]

# %%
plt.style.use("seaborn-v0_8-whitegrid")
dpi = 400
plt.figure(figsize=(12, 8), dpi=dpi)
plt.plot(data['timestamp'], data['lux'], label='Light Intensity (lux)', color='darkviolet')
plt.xlabel("Time Stamp", fontsize=12, weight="bold")
plt.ylabel("Light Intensity (in Lux)", fontsize=12, weight="bold")
plt.title("Light Intensity (in Lux)", fontsize=16, weight="bold")
plt.legend()
plt.grid(linestyle="--", alpha=0.8)
plt.show()
